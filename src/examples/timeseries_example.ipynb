# %%
import openseespy.opensees as ops

# Import from package level
from apeSees.timeseries import ASCE41Protocol, LinearTimeSeries

# Or import specific modules
from apeSees.timeseries.protocols import ASCE41Protocol
from apeSees.timeseries.basic import LinearTimeSeries

# Create and use
protocol = ASCE41Protocol(tag=1, max_disp=0.02)
protocol.build(verbose=True)
protocol.plot()

linear = LinearTimeSeries(tag=2, factor=2.5)
linear.build()
# Out:
# ops.timeSeries("Path", 1, "-time", 0.0, 0.0014204545454545455, 0.004261363636363636, 0.007102272727272727, 0.009943181818181818, 0.01278409090909091, 0.015625, 0.019886363636363636, 0.02556818181818182, 0.03125, 0.036931818181818184, 0.04261363636363636, 0.048295454545454544, 0.05539772727272728, 0.06392045454545454, 0.07244318181818181, 0.08096590909090907, 0.08948863636363634, 0.0980113636363636, 0.10795454545454541, 0.11931818181818178, 0.13068181818181815, 0.1420454545454545, 0.15340909090909088, 0.16477272727272724, 0.17897727272727268, 0.1960227272727272, 0.21306818181818174, 0.2301136363636363, 0.24715909090909086, 0.2642045454545454, 0.284090909090909, 0.30681818181818177, 0.3295454545454545, 0.3522727272727272, 0.37499999999999994, 0.39772727272727265, 0.42613636363636354, 0.46022727272727265, 0.49431818181818177, 0.5284090909090909, 0.5681818181818181, 0.6136363636363635, 0.6590909090909091, 0.7045454545454545, 0.7613636363636362, 0.8295454545454545, 0.8977272727272727, 0.9
# ...
